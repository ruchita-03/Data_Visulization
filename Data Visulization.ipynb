# %%
import pandas as pd

# 1. CSV file importing
df_csv = pd.read_csv('etrm_trades.csv')
print("CSV DataFrame:")
display(df_csv)
# Out:
# CSV DataFrame:
#     TradeID Commodity TradeType  Volume   Price Currency DeliveryStart  \
# 0         1     Power       BUY  193.52  191.13      GBP    2025-01-08
# 1         2       Gas       BUY  368.68  127.76      GBP    2025-01-29
# 2         3     Power      SELL   86.45   48.08      USD    2025-01-03
# 3         4       Gas       BUY   38.46  175.91      GBP    2025-01-23
# 4         5      Coal       BUY  304.55  147.45      EUR    2025-01-09
# ..      ...       ...       ...     ...     ...      ...           ...
# 95       96      Coal      SELL   55.62  181.50      EUR    2025-01-05
# 96       97     Power       BUY  451.20  133.96      EUR    2025-01-06
# 97       98      Coal       BUY  176.12   82.86      GBP    2025-01-30
# 98       99     Power      SELL  365.72  181.48      USD    2025-01-22
# 99      100       Oil      SELL  444.67  160.38      GBP    2025-01-29
#
#    DeliveryEnd Periodicity
# 0   2025-01-16     Monthly
# 1   2025-02-16   Quarterly
# ...

# %%
# 2. Converting json file 
df_json=pd.read_json('etrm_trades.json')
print("JSON DataFrame: ")
display(df_json)
# Out:
# JSON DataFrame:
#     TradeID Commodity TradeType  Volume   Price Currency DeliveryStart  \
# 0         1     Power       BUY  193.52  191.13      GBP    2025-01-08
# 1         2       Gas       BUY  368.68  127.76      GBP    2025-01-29
# 2         3     Power      SELL   86.45   48.08      USD    2025-01-03
# 3         4       Gas       BUY   38.46  175.91      GBP    2025-01-23
# 4         5      Coal       BUY  304.55  147.45      EUR    2025-01-09
# ..      ...       ...       ...     ...     ...      ...           ...
# 95       96      Coal      SELL   55.62  181.50      EUR    2025-01-05
# 96       97     Power       BUY  451.20  133.96      EUR    2025-01-06
# 97       98      Coal       BUY  176.12   82.86      GBP    2025-01-30
# 98       99     Power      SELL  365.72  181.48      USD    2025-01-22
# 99      100       Oil      SELL  444.67  160.38      GBP    2025-01-29
#
#    DeliveryEnd Periodicity
# 0   2025-01-16     Monthly
# 1   2025-02-16   Quarterly
# ...

# %%
#3. converting the excel file into dataframe
df_excel=pd.read_excel('etrm_trades.xlsx',sheet_name=0)
print(" Excel DataFrame: ")
display(df_excel)
# Out:
#  Excel DataFrame:
#     TradeID Commodity TradeType  Volume   Price Currency DeliveryStart  \
# 0         1     Power       BUY  193.52  191.13      GBP    2025-01-08
# 1         2       Gas       BUY  368.68  127.76      GBP    2025-01-29
# 2         3     Power      SELL   86.45   48.08      USD    2025-01-03
# 3         4       Gas       BUY   38.46  175.91      GBP    2025-01-23
# 4         5      Coal       BUY  304.55  147.45      EUR    2025-01-09
# ..      ...       ...       ...     ...     ...      ...           ...
# 95       96      Coal      SELL   55.62  181.50      EUR    2025-01-05
# 96       97     Power       BUY  451.20  133.96      EUR    2025-01-06
# 97       98      Coal       BUY  176.12   82.86      GBP    2025-01-30
# 98       99     Power      SELL  365.72  181.48      USD    2025-01-22
# 99      100       Oil      SELL  444.67  160.38      GBP    2025-01-29
#
#    DeliveryEnd Periodicity
# 0   2025-01-16     Monthly
# 1   2025-02-16   Quarterly
# ...

# %%
#4. Txt file converting into DataFrame
df_txt=pd.read_csv('etrm_trades.txt',sep='\t')
print("Txt DataFrame is  :")
display(df_txt)
# Out:
# Txt DataFrame is  :
#    TradeID|Commodity|TradeType|Volume|Price|Currency|DeliveryStart|DeliveryEnd|Periodicity
# 0   1|Power|BUY|193.52|191.13|GBP|2025-01-08|2025-...
# 1   2|Gas|BUY|368.68|127.76|GBP|2025-01-29|2025-02...
# 2   3|Power|SELL|86.45|48.08|USD|2025-01-03|2025-0...
# 3   4|Gas|BUY|38.46|175.91|GBP|2025-01-23|2025-02-...
# 4   5|Coal|BUY|304.55|147.45|EUR|2025-01-09|2025-0...
# ..                                                ...
# 95  96|Coal|SELL|55.62|181.5|EUR|2025-01-05|2025-0...
# 96  97|Power|BUY|451.2|133.96|EUR|2025-01-06|2025-...
# 97  98|Coal|BUY|176.12|82.86|GBP|2025-01-30|2025-0...
# 98  99|Power|SELL|365.72|181.48|USD|2025-01-22|202...
# 99  100|Oil|SELL|444.67|160.38|GBP|2025-01-29|2025...
#
# [100 rows x 1 columns]

# %%
# 5. HTML
df_html=pd.read_html('etrm_trades.html')[0]
print("HTML DataFrame:")
display(df_html)
# Out:
# HTML DataFrame:
#     TradeID Commodity TradeType  Volume   Price Currency DeliveryStart  \
# 0         1     Power       BUY  193.52  191.13      GBP    2025-01-08
# 1         2       Gas       BUY  368.68  127.76      GBP    2025-01-29
# 2         3     Power      SELL   86.45   48.08      USD    2025-01-03
# 3         4       Gas       BUY   38.46  175.91      GBP    2025-01-23
# 4         5      Coal       BUY  304.55  147.45      EUR    2025-01-09
# ..      ...       ...       ...     ...     ...      ...           ...
# 95       96      Coal      SELL   55.62  181.50      EUR    2025-01-05
# 96       97     Power       BUY  451.20  133.96      EUR    2025-01-06
# 97       98      Coal       BUY  176.12   82.86      GBP    2025-01-30
# 98       99     Power      SELL  365.72  181.48      USD    2025-01-22
# 99      100       Oil      SELL  444.67  160.38      GBP    2025-01-29
#
#    DeliveryEnd Periodicity
# 0   2025-01-16     Monthly
# 1   2025-02-16   Quarterly
# ...

# %%
from lxml import etree

# converting the xml file into DataFrame
tree = etree.parse('etrm_trades.xml')
root = tree.getroot()
data = []
for trade in root.findall('Trade'):
    trade_data = {
        'TradeID': int(trade.find('TradeID').text),
        'Commodity': trade.find('Commodity').text,
        'TradeType': trade.find('TradeType').text,
        'Volume': float(trade.find('Volume').text),
        'Price': float(trade.find('Price').text),
        'Currency': trade.find('Currency').text,
        'DeliveryStart': trade.find('DeliveryStart').text,
        'DeliveryEnd': trade.find('DeliveryEnd').text,
        'Periodicity': trade.find('Periodicity').text
    }
    data.append(trade_data)

df_xml = pd.DataFrame(data)
print("XML DataFrame:")
display(df_xml)
# Out:
# XML DataFrame:
#     TradeID Commodity TradeType  Volume   Price Currency DeliveryStart  \
# 0         1     Power       BUY  193.52  191.13      GBP    2025-01-08
# 1         2       Gas       BUY  368.68  127.76      GBP    2025-01-29
# 2         3     Power      SELL   86.45   48.08      USD    2025-01-03
# 3         4       Gas       BUY   38.46  175.91      GBP    2025-01-23
# 4         5      Coal       BUY  304.55  147.45      EUR    2025-01-09
# ..      ...       ...       ...     ...     ...      ...           ...
# 95       96      Coal      SELL   55.62  181.50      EUR    2025-01-05
# 96       97     Power       BUY  451.20  133.96      EUR    2025-01-06
# 97       98      Coal       BUY  176.12   82.86      GBP    2025-01-30
# 98       99     Power      SELL  365.72  181.48      USD    2025-01-22
# 99      100       Oil      SELL  444.67  160.38      GBP    2025-01-29
#
#    DeliveryEnd Periodicity
# 0   2025-01-16     Monthly
# 1   2025-02-16   Quarterly
# ...

# %%
df_csv.dtypes
# Out:
# TradeID            int64
# Commodity         object
# TradeType         object
# Volume           float64
# Price            float64
# Currency          object
# DeliveryStart     object
# DeliveryEnd       object
# Periodicity       object
# dtype: object

# %%
df_html.dtypes
# Out:
# TradeID            int64
# Commodity         object
# TradeType         object
# Volume           float64
# Price            float64
# Currency          object
# DeliveryStart     object
# DeliveryEnd       object
# Periodicity       object
# dtype: object

# %%
df_json.dtypes
# Out:
# TradeID            int64
# Commodity         object
# TradeType         object
# Volume           float64
# Price            float64
# Currency          object
# DeliveryStart     object
# DeliveryEnd       object
# Periodicity       object
# dtype: object

# %%
df_xml.dtypes
# Out:
# TradeID            int64
# Commodity         object
# TradeType         object
# Volume           float64
# Price            float64
# Currency          object
# DeliveryStart     object
# DeliveryEnd       object
# Periodicity       object
# dtype: object

# %%
df_txt.dtypes
# Out:
# TradeID|Commodity|TradeType|Volume|Price|Currency|DeliveryStart|DeliveryEnd|Periodicity    object
# dtype: object

# %%
df_excel.dtypes
# Out:
# TradeID            int64
# Commodity         object
# TradeType         object
# Volume           float64
# Price            float64
# Currency          object
# DeliveryStart     object
# DeliveryEnd       object
# Periodicity       object
# dtype: object

# %%
# Convert both columns to datetime because they are imported as string
df_csv['DeliveryStart'] = pd.to_datetime(df_csv['DeliveryStart'], errors='coerce')
df_csv['DeliveryEnd'] = pd.to_datetime(df_csv['DeliveryEnd'], errors='coerce')


print(df_csv.dtypes)
# Out:
# TradeID                   int64
# Commodity                object
# TradeType                object
# Volume                  float64
# Price                   float64
# Currency                 object
# DeliveryStart    datetime64[ns]
# DeliveryEnd      datetime64[ns]
# Periodicity              object
# dtype: object

# %%
#Average Price per Commodity
# Group by Commodity and calculate average price
avg_price_per_commodity = df_csv.groupby('Commodity')['Price'].mean().sort_values(ascending=False)

print("Average Price per Commodity:")
print(avg_price_per_commodity)
# Out:
# Average Price per Commodity:
# Commodity
# Gas      119.778437
# Coal     104.642941
# Oil      101.757826
# Power    100.469643
# Name: Price, dtype: float64

# %%
#Distribution of Trades by Currency
import matplotlib.pyplot as plt

# Count trades by Currency
currency_distribution = df_csv['Currency'].value_counts()

print("Distribution of Trades by Currency:")
print(currency_distribution)

currency_distribution.plot(kind='bar', figsize=(6,4), title="Trades Distribution by Currency")
plt.xlabel("Currency")
plt.ylabel("Number of Trades")
plt.show()
# Out:
# Distribution of Trades by Currency:
# Currency
# GBP    38
# USD    34
# EUR    28
# Name: count, dtype: int64

# %%
#Trade Periodicity Breakdown
# Ensure DeliveryStart is datetime
df_csv['DeliveryStart'] = pd.to_datetime(df_csv['DeliveryStart'], errors='coerce')

# Daily trades
daily_trades = df_csv.groupby(df_csv['DeliveryStart'].dt.date).size()

# Weekly trades
weekly_trades = df_csv.groupby(df_csv['DeliveryStart'].dt.to_period('W')).size()

# Monthly trades
monthly_trades = df_csv.groupby(df_csv['DeliveryStart'].dt.to_period('M')).size()

print("Daily Trades:\n", daily_trades.head())
print("\nWeekly Trades:\n", weekly_trades.head())
print("\nMonthly Trades:\n", monthly_trades.head())
# Out:
# Daily Trades:
#  DeliveryStart
# 2025-01-01    1
# 2025-01-02    3
# 2025-01-03    3
# 2025-01-04    2
# 2025-01-05    1
# dtype: int64
#
# Weekly Trades:
#  DeliveryStart
# 2024-12-30/2025-01-05    10
# 2025-01-06/2025-01-12    30
# 2025-01-13/2025-01-19    18
# 2025-01-20/2025-01-26    22
# 2025-01-27/2025-02-02    20
# Freq: W-SUN, dtype: int64
#
# Monthly Trades:
#  DeliveryStart
# 2025-01    100
# Freq: M, dtype: int64

# %%
#Trade Volume by Commodity
trade_volume = df_csv.groupby('Commodity')['Volume'].sum().sort_values(ascending=False)
print(trade_volume)
trade_volume.plot(kind='bar', figsize=(8,5), title="Total Trade Volume by Commodity")
# Out:
# Commodity
# Gas      7442.02
# Power    6735.49
# Oil      5594.38
# Coal     4799.25
# Name: Volume, dtype: float64
# <Axes: title={'center': 'Total Trade Volume by Commodity'}, xlabel='Commodity'>

# %%
#Bar Chart: Volume by Trader
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
plt.bar(volume_by_commodity.index, volume_by_commodity.values, color=plt.cm.viridis(range(len(volume_by_commodity))))
plt.title('Total Volume by Commodity', fontsize=16)
plt.xlabel('Commodity')
plt.ylabel('Total Volume')
plt.xticks(rotation=45)
plt.show()

# %%
# Out:
# Index(['Tradeid', 'Commodity', 'Tradetype', 'Volume', 'Price', 'Currency',
#        'Deliverystart', 'Deliveryend', 'Periodicity', 'Notional'],
#       dtype='object')

# %%
df_csv.columns = df_csv.columns.str.strip()  # removes leading/trailing spaces
df_csv.columns = df_csv.columns.str.title()  # makes first letter uppercase
print(df_csv.columns)
# Out:
# Index(['Tradeid', 'Commodity', 'Tradetype', 'Volume', 'Price', 'Currency',
#        'Deliverystart', 'Deliveryend', 'Periodicity', 'Notional'],
#       dtype='object')

# %%
#Pie Chart: Trades by Currency
currency_counts = df_csv['Currency'].value_counts()
plt.figure(figsize=(7,7))
plt.pie(currency_counts, labels=currency_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Trades by Currency', fontsize=16)
plt.show()

# %%
df_csv.columns = df_csv.columns.str.strip().str.lower()

df_csv['deliverystart'] = pd.to_datetime(df_csv['deliverystart'])


avg_price_by_date = df_csv.groupby('deliverystart')['price'].mean()


plt.figure(figsize=(12,6))
plt.plot(avg_price_by_date.index, avg_price_by_date.values, marker='o', color='blue')
plt.title('Average Price Trend by Delivery Start Date', fontsize=16)
plt.xlabel('Delivery Start Date')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
#Histogram: Distribution of Notional Values

import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(df_csv['notional'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Notional Values', fontsize=16)
plt.xlabel('Notional Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Heatmap: Trade Counts by Commodity and Trade Type
import matplotlib.pyplot as plt
import seaborn as sns

#  Commodity vs Trade Type counts
trade_counts = df_csv.pivot_table(
    index='commodity',
    columns='tradetype',
    values='volume',   # lowercase
    aggfunc='count',
    fill_value=0
)

plt.figure(figsize=(12,6))
sns.heatmap(trade_counts, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Trade Counts: Commodity vs Trade Type', fontsize=16)
plt.xlabel('Trade Type')
plt.ylabel('Commodity')
plt.show()

# %%
#Scatter Plot: Price vs Volume by Commodity
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df_csv,
    x='volume',
    y='price',
    hue='commodity',
    palette='tab10'
)
plt.title('Price vs Volume by Commodity', fontsize=16)
plt.xlabel('Volume')
plt.ylabel('Price')
plt.legend(title='Commodity', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#Box Plot: Notional Values by Commodity
plt.figure(figsize=(12,6))
sns.boxplot(data=df_csv, x='commodity', y='notional', palette='Set3', hue='commodity', dodge=False, legend=False)
plt.title('Notional Value Distribution by Commodity', fontsize=16)
plt.xlabel('Commodity')
plt.ylabel('Notional Value')
plt.xticks(rotation=45)
plt.show()
